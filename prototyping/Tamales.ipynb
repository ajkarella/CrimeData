# %%
import pandas as pd

# %%
# df = pd.read_json('https://data.cityofnewyork.us/resource/8h9b-rp9u.json')
# https://data.cityofnewyork.us/resource/8h9b-rp9u.json?$offset=1000
df=pd.read_json('https://data.cityofnewyork.us/resource/8h9b-rp9u.json')

# %%
5000000/1000
# Out:
# 5000.0

# %%
j=0
df=pd.read_json('https://data.cityofnewyork.us/resource/8h9b-rp9u.json?$offset=%s'%j)
df
# Out:
#      arrest_key              arrest_date  pd_cd  \
# 0      32311380  2007-06-18T00:00:00.000  511.0
# 1     192799737  2019-01-26T00:00:00.000  177.0
# 2     193260691  2019-02-06T00:00:00.000    NaN
# 3     149117452  2016-01-06T00:00:00.000  153.0
# 4     190049060  2018-11-15T00:00:00.000  157.0
# ..          ...                      ...    ...
# 995   195233075  2019-03-27T00:00:00.000  922.0
# 996   192144034  2019-01-10T00:00:00.000  490.0
# 997   198095266  2019-06-05T00:00:00.000  439.0
# 998   195839534  2019-04-10T00:00:00.000  259.0
# 999   195366427  2019-03-30T00:00:00.000  101.0
#
#                                        pd_desc  ky_cd  \
# 0           CONTROLLED SUBSTANCE, POSSESSION 7  235.0
# 1                                 SEXUAL ABUSE  116.0
# 2                                          NaN    NaN
# 3                                       RAPE 3  104.0
# 4                                       RAPE 1  104.0
# ..                                         ...    ...
# ...

# %% [markdown]
# # Heree is wokring one

# %%
fdb=pd.DataFrame()
for i in range(100):
    j=i*1000
    print(j)
    df=pd.read_json('https://data.cityofnewyork.us/resource/8h9b-rp9u.json?$offset=%s'%j)
    fdb=pd.concat([fdb,df])
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000

# %%
fdb=fdb.reset_index(drop=True)

# %%
fdb
